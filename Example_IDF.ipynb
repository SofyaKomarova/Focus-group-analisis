# %%
from gensim import corpora, matutils, models, similarities
from gensim.similarities.docsim import MatrixSimilarity

# %%
fname = input('Enter File: ')
if len(fname) < 1 : fname = 'Focus_Group_Transcribtion.txt'
documents = open(fname)
# Out:
# Enter File: Focus_Group_Transcribtion.txt

# %%
fname = input('Enter File: ') if len(fname) < 1 : fname = 'Focus_Group_Transcribtion.txt' documents = open(fname)
# Out:
#   File "<ipython-input-9-8f1c8ee5bc3e>", line 1
#     fname = input('Enter File: ') if len(fname) < 1 : fname = 'Focus_Group_Transcribtion.txt' documents = open(fname)
#                                                     ^
# SyntaxError: invalid syntax

# %%
word_list = []
for doc in documents:
    word_list.append(re.findall('(\\w+)', doc.lower()))
    
word_list
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-5bae8b4cf5ba> in <module>
#       1 word_list = []
# ----> 2 for doc in documents:
#       3     word_list.append(re.findall('(\\w+)', doc.lower()))
#       4
#       5 word_list
#
# /opt/anaconda3/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x9d in position 164: invalid start byte

# %%
lexicon = corpora.Dictionary(word_list)

# %%
lexicon.token2id
# Out:
# {}

# %%
lexicon.token2id['bambini']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-def3ab622551> in <module>
# ----> 1 lexicon.token2id['bambini']
#
# KeyError: 'bambini'

# %%
lexicon[3]

# %%
print(word_list[0])

# %%
lexicon.doc2bow(word_list[0])

# %%
bow = []
for t in word_list:
    bow.append(lexicon.doc2bow(t))
    
bow

# %%
tf_array = matutils.corpus2dense(bow, num_terms=len(lexicon.token2id))
tf_array

# %%
tf_sparse_array = matutils.corpus2csc(bow)
tf_sparse_array

# %%
tfidf = models.TfidfModel(bow)
print(tfidf)

# %%
tfidf[bow[:1]]

# %%
lexicon[9]

# %%
tf_obj = tfidf[bow[:1]]
sorted(tf_obj, key=lambda x: x[1], reverse=True)[:5]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import numpy as np
import pandas as pd
import re

# %%
sentences = list()
with open("filteredtext620.txt") as file:
    for line in file:
        for l in re.split(r"\.\s|\?\s|\!\s|\n",line):
            if l:
                sentences.append(l)
print(sentences)
# Out:
# [' Va va Come Bella iniziata Ho detto studio lavoro amiko studio sviluppa guida insegnarci persone sviluppo Software tecnologico aiutare bambini semplici aipi sviluppa creazioni detta pazienza tecnologia Usiamo chest wound sensi linguaggi atra progetto parlo dopo prima voglio fare introduzione dopo libere sente meno paura Ecco vuoi sapere OK vabbè vado Monica lavoro Cugi Comune Bologna seguo nidi scuole dellinfanzia tema creatività poi Così pensato partecipare focus gruppo interessa tema interessa largomento laltro argomento ultimamente trascurando Come riflessione servizi seguo insegnanti educatrici tema creatività viene tanto affrontato spesso dobbiamo soprattutto anni ragionare aspetti sicurezza tante limitazioni Dentro servizi pur garantendo bambini avere buona giornata diciamo fatto avere gruppi chiusi bambini devono sempre stare certi spazi usare tanti materiali poi materiali vanno igienizzati scuola tempo Covid diversa bambini meno accesso varietà esperienze pensato partecipar
# ...

# %%
cvec = CountVectorizer (stop_words='english', min_df=2, max_df=0.4, ngram_range=(2,2))
sf = cvec.fit_transform(sentences)
print(sf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-08b273ffe1f8> in <module>
#       1 cvec = CountVectorizer (stop_words='english', min_df=2, max_df=0.4, ngram_range=(2,2))
# ----> 2 sf = cvec.fit_transform(sentences)
#       3 print(sf)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1211                              else min_df * n_doc)
#    1212             if max_doc_count < min_doc_count:
# -> 1213                 raise ValueError(
#    1214                     "max_df corresponds to < documents than min_df")
#    1215             X, self.stop_words_ = self._limit_features(X, vocabulary,
#
# ValueError: max_df corresponds to < documents than min_df

# %%
transformer = TfidfTransformer()
transformed_weights = transformer.fit_transform(sf)
weights = np.asarray(transformed_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': cvec.get_feature_names(), 'weight': weights})
print(weights_df)
# Out:
#                     term    weight
# 0                10 anni  0.004133
# 1          altri bambini  0.007264
# 2                anch io  0.005297
# 3                anni fa  0.006512
# 4     attività proponevo  0.004175
# 5        bambini diversi  0.003424
# 6     bambini esprimersi  0.003842
# 7     dell immaginazione  0.005624
# 8           diversi tipi  0.003424
# 9           fare ipotesi  0.002224
# 10             fare modo  0.004175
# 11          fermo attimo  0.004843
# 12  importante preparare  0.003424
# 13   insegnante sostegno  0.004843
# 14      ipotesi sviluppo  0.002224
# 15      lavagna luminosa  0.004843
# 16         lavoro scuola  0.004175
# 17   livello tecnologico  0.004843
# 18            magic room  0.007172
# 19        movimento mano  0.004843
# 20   pensato partecipare  0.004843
# 21       pensavo esempio  0.003689
# 22      possiamo pensare  0.003702
# 23   possibilità bambini  0.003842
# 24     preparare bambini  0.003424
# 25           punto vista  0.007264
# ...

# %%
weights_df.sort_values(by='weight', ascending=False).head(49)
# Out:
#                     term    weight
# 39            vita reale  0.007264
# 25           punto vista  0.007264
# 1          altri bambini  0.007264
# 18            magic room  0.007172
# 27       scuola primaria  0.006512
# 3                anni fa  0.006512
# 35        tutte attività  0.006049
# 7     dell immaginazione  0.005624
# 29           stanza tipo  0.005442
# 2                anch io  0.005297
# 17   livello tecnologico  0.004843
# 36               va bene  0.004843
# 34       tema creatività  0.004843
# 33                 sì ma  0.004843
# 31       sviluppo alcune  0.004843
# 19        movimento mano  0.004843
# 20   pensato partecipare  0.004843
# 11          fermo attimo  0.004843
# 13   insegnante sostegno  0.004843
# 15      lavagna luminosa  0.004843
# 16         lavoro scuola  0.004175
# 4     attività proponevo  0.004175
# 30  stimolare creatività  0.004175
# 10             fare modo  0.004175
# 38           viene mente  0.004133
# 37      vengono proposte  0.004133
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import numpy as np
import pandas as pd
import re

# %%
sentences = list()
with open("filteredtext623.txt") as file:
    for line in file:
        for l in re.split(r"\.\s|\?\s|\!\s|\n",line):
            if l:
                sentences.append(l)
print(sentences)
# Out:
# [' Va va Come Bella iniziata Ho detto studio lavoro amiko studio sviluppa guida insegnarci persone sviluppo Software tecnologico aiutare bambini semplici aipi sviluppa creazioni detta pazienza tecnologia Usiamo chest wound sensi linguaggi atra progetto parlo voglio fare introduzione libere sente meno paura Ecco vuoi sapere OK vabbè vado Monica lavoro Cugi Comune Bologna seguo nidi scuole dellinfanzia tema creatività poi Così pensato partecipare focus gruppo interessa tema interessa largomento laltro argomento ultimamente trascurando Come riflessione servizi seguo insegnanti educatrici tema creatività viene tanto affrontato spesso dobbiamo soprattutto anni ragionare aspetti sicurezza tante limitazioni Dentro servizi pur garantendo bambini avere buona giornata diciamo fatto avere gruppi chiusi bambini devono stare certi spazi usare tanti materiali poi materiali vanno igienizzati scuola tempo Covid diversa bambini meno accesso varietà esperienze pensato partecipare incontro mettere test
# ...

# %%
cvec = CountVectorizer(min_df=0.4, max_df=2, ngram_range=(2,2))
sf = cvec.fit_transform(sentences)
print(sf)
# Out:
#   (0, 1648)	3
#   (0, 1645)	3
#   (0, 307)	3
#   (0, 210)	3
#   (0, 762)	3
#   (0, 725)	3
#   (0, 474)	3
#   (0, 1514)	3
#   (0, 815)	3
#   (0, 78)	3
#   (0, 1515)	3
#   (0, 1533)	3
#   (0, 720)	3
#   (0, 768)	3
#   (0, 1080)	3
#   (0, 1539)	3
#   (0, 1422)	3
#   (0, 1556)	3
#   (0, 41)	3
#   (0, 188)	3
#   (0, 1354)	3
#   (0, 37)	3
#   (0, 1532)	3
#   (0, 414)	3
#   (0, 469)	3
#   :	:
#   (0, 890)	3
#   (0, 182)	3
#   (0, 1051)	3
#   (0, 1136)	3
#   (0, 1491)	3
#   (0, 397)	3
#   (0, 940)	3
#   (0, 538)	3
#   (0, 1266)	3
#   (0, 706)	3
#   (0, 1330)	3
#   (0, 1679)	3
#   (0, 1281)	3
#   (0, 945)	3
#   (0, 1252)	3
#   (0, 1253)	3
#   (0, 1456)	3
#   (0, 236)	3
#   (0, 82)	3
#   (0, 238)	3
#   (0, 1327)	3
#   (0, 1457)	3
#   (0, 1257)	3
#   (0, 157)	3
#   (0, 678)	2

# %%
transformer = TfidfTransformer()
transformed_weights = transformer.fit_transform(sf)
weights = np.asarray(transformed_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': cvec.get_feature_names(), 'weight': weights})
print(weights_df)
# Out:
#                term    weight
# 0           10 anni  0.046257
# 1         10 potere  0.023128
# 2          100 anni  0.023128
# 3           11 anni  0.023128
# 4     111 soluzione  0.023128
# ...             ...       ...
# 1722  vuole secondo  0.023128
# 1723  whitacre ziua  0.023128
# 1724    wound sensi  0.023128
# 1725      zero anni  0.023128
# 1726   ziua aiutare  0.023128
#
# [1727 rows x 2 columns]

# %%
weights_df.sort_values(by='weight', ascending=False).head(50)
# Out:
#                             term   weight
# 868                   magic room  0.09212
# 1212                 punto vista  0.06909
# 1488                 stanza tipo  0.06909
# 1724                  vita reale  0.06909
# 1333             scuola primaria  0.06909
# 1553  sviluppo dellimmaginazione  0.06909
# 89                       anni fa  0.06909
# 66                 altri bambini  0.06909
# 759         importante preparare  0.04606
# 1707                 viene mente  0.04606
# 540                 diversi tipi  0.04606
# 633                facete dentro  0.04606
# 1574             tema creatività  0.04606
# 1067         pensato partecipare  0.04606
# 1144         possibilità bambini  0.04606
# 175              bambini diversi  0.04606
# 1551             sviluppo alcune  0.04606
# 826                lavoro scuola  0.04606
# 1165           preparare bambini  0.04606
# 855          livello tecnologico  0.04606
# 1475           spettro autistico  0.04606
# ...

# %%
f1 = open('filteredtext6.txt', 'r')
f2 = open('file2.txt', 'w')
for line in f1:
    f2.write(line.replace(''  , 'potere'))
f1.close()
f2.close()

# %%
infile = "filteredtext.txt"
outfile = "cleaned_file1.txt"

delete_list = ["sì", "ah", "cosa","Va"]
with open(infile) as fin, open(outfile, "w+") as fout:
    for line in fin:
        for word in delete_list:
            line = line.replace(word, "")
            fout.write(line)

# %%
with open(r'filteredtext611.txt', 'r') as infile, \
     open(r'filteredtext616.txt', 'w') as outfile:
    data = infile.read()
    data = data.replace("?", "")
    outfile.write(data)
