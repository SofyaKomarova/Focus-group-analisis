# %%
# Out:
# Enter File: filteredtext9.txt

# %%
fname = input('Enter File: ')
if len(fname) < 1 : fname = 'Focus_Group_Transcribtion.txt'
hand = open(fname)

di = dict()

for lin in hand:
    lin = lin.rstrip()
    wds = lin.split()
    for w in wds:
        di[w] = di.get(w,0)+1
        
#print(di)
# Out:
# Enter File: filteredtext612.txt

# %%
tmp = list()
for k, v in di.items():
    newt = (v,k)
    tmp.append(newt)
    
print('Flipped',tmp)
# Out:
# Flipped [(6, 'Va'), (9, 'va'), (15, 'Come'), (3, 'Bella'), (3, 'iniziata'), (6, 'Ho'), (12, 'detto'), (9, 'studio'), (18, 'lavoro'), (3, 'amiko'), (6, 'sviluppa'), (3, 'guida'), (3, 'insegnarci'), (6, 'persone'), (21, 'sviluppo'), (3, 'Software'), (9, 'tecnologico'), (12, 'aiutare'), (120, 'bambini'), (3, 'semplici'), (3, 'aipi'), (3, 'creazioni'), (6, 'detta'), (3, 'pazienza'), (6, 'tecnologia'), (3, 'Usiamo'), (3, 'chest'), (3, 'wound'), (3, 'sensi'), (3, 'linguaggi'), (3, 'atra'), (3, 'progetto'), (6, 'parlo'), (21, 'dopo'), (15, 'prima'), (6, 'voglio'), (36, 'fare'), (3, 'introduzione'), (99, 'essere'), (3, 'libere'), (9, 'sente'), (21, 'meno'), (3, 'paura'), (6, 'Ecco'), (3, 'vuoi'), (6, 'sapere'), (3, 'OK'), (9, 'vabbè'), (3, 'vado'), (9, 'Monica'), (3, 'Cugi'), (3, 'Comune'), (3, 'Bologna'), (6, 'seguo'), (3, 'nidi'), (12, 'scuole'), (3, 'dellinfanzia'), (12, 'tema'), (15, 'creatività'), (63, 'poi'), (3, 'Così'), (9, 'pensato'), (6, 'partecipare'), (6, 'focus'), (9, 'gruppo'), (6, 'interessa'), (3, 'largomento'), (6, 'laltro'), (3, 'argomento'), (3, 'ultimamente'), (3, 'trascurando'), (3, 'riflessione'), (6, 'servizi'), (6, 'insegnanti'), (3, 'educatrici'), (12, 'viene'), (15, 'tanto'), (3, 'affrontato'), (3, 'spesso'), (3, 'dobbiamo'), (6, 'soprattutto'), (33, 'anni'), (3, 'ragionare'), (3, 'molti'), (3, 'aspetti'), (3, 'sicurezza'), (6, 'tante'), (3, 'limitazioni'), (3, 'Dentro'), (3, 'pur'), (3, 'garantendo'), (6, 'poter'), (12, 'avere'), (3, 'buona'), (3, 'giornata'), (21, 'diciamo'), (21, 'fatto'), (3, 'gruppi'), (3, 'chiusi'), (9, 'devono'), (21, 'sempre'), (18, 'stare'), (6, 'certi'), (6, 'spazi'), (12, 'usare'), (3, 'tanti'), (45, 'materiali'), (3, 'vanno'), (3, 'igienizzati'), (30, 'scuola'), (9, 'tempo'), (3, 'Covid'), (9, 'diversa'), (3, 'accesso'), (3, 'varietà'), (6, 'esperienze'), (3, 'incontro'), (6, 'mettere'), (6, 'testa'), (3, 'Idee'), (6, 'ricominciare'), (3, 'riflettere'), (9, 'fermo'), (6, 'attimo'), (27, 'punto'), (27, 'interessante'), (9, 'oggettive'), (90, 'molto'), (24, 'importante'), (6, 'aggettivi'), (12, 'visto'), (3, 'Molti'), (3, 'uccelli'), (6, 'I'), (3, 've'), (9, 'intanto'), (12, 'Camilla'), (3, 'Presento'), (6, 'Sofia'), (3, 'Eravamo'), (3, 'sentiti'), (3, 'email'), (12, 'primaria'), (3, 'uninsegnante'), (6, 'sostegno'), (6, 'tre'), (3, 'terzo'), (6, 'anno'), (3, 'vicino'), (6, 'casa'), (6, '50'), (3, 'm'), (6, 'scelta'), (3, 'comodo'), (3, 'definisco'), (3, 'tradizionale'), (3, 'daltronde'), (3, 'stragrande'), (3, 'maggioranza'), (3, 'Italia'), (3, 'Scuola'), (12, 'lavorato'), (3, '7'), (3, 'centro'), (3, 'internazionale'), (6, 'malaguzzi'), (6, 'insegnante'), (3, 'cominciato'), (9, 'unesperienza'), (3, 'pregressa'), (3, 'tranne'), (3, 'Alda'), (3, 'simile'), (3, 'subito'), (3, 'squadra'), (6, 'lavora'), (3, 'critica'), (6, 'sotto'), (6, 'Diciamo'), (3, 'sesto'), (6, 'esperienza'), (3, 'formativa'), (6, 'stimolante'), (3, 'aritmico'), (18, 'così'), (3, 'Praticamente'), (3, 'cambia'), (3, 'specifico'), (3, 'racconto'), (3, 'lavoravamo'), (6, 'praticamente'), (9, '10'), (3, '8'), (6, 'spettro'), (9, 'autistico'), (3, 'Con'), (3, 'atipico'), (6, 'seguito'), (6, 'master'), (3, 'unimore'), (3, 'sullautismo'), (3, 'Era'), (3, 'lho'), (6, 'trovato'), (3, 'teorico'), (3, 'stato'), (3, 'nessuna'), (3, 'conoscenza'), (12, 'disturbo'), (3, 'conoscenze'), (3, 'potevano'), (3, 'potevo'), (3, 'aver'), (3, 'ricevuto'), (3, 'precedente'), (3, 'formazione'), (3, 'strategie'), (3, 'sapevo'), (6, 'ben'), (3, 'poco'), (9, 'vero'), (9, 'lesperienza'), (3, 'acquisisce'), (3, 'lavorando'), (6, 'solito'), (6, 'mai'), (3, 'utile'), (15, 'Insomma'), (3, 'alcuni'), (3, 'casi'), (21, 'fa'), (6, 'campo'), (6, 'semplicemente'), (6, 'finché'), (3, 'trovi'), (6, 'davanti'), (3, 'situazione'), (3, 'risolvere'), (15, 'immagini'), (3, 'Quale'), (6, 'soluzione'), (3, 'letto'), (3, 'straletto'), (3, 'Soluzioni'), (3, 'dorsale'), (3, 'Levi'), (3, 'vino'), (12, 'veramente'), (3, 'conosci'), (9, 'vale'), (3, 'generale'), (9, ...

# %%
tmp = sorted(tmp, reverse = True)
print('Sorted',tmp)
# Out:
# Sorted [(120, 'bambini'), (99, 'essere'), (90, 'molto'), (63, 'poi'), (51, 'attività'), (45, 'materiali'), (42, 'esempio'), (36, 'so'), (36, 'fare'), (33, 'stanza'), (33, 'anni'), (30, 'scuola'), (27, 'punto'), (27, 'interessante'), (24, 'importante'), (24, 'dire'), (24, 'dentro'), (24, 'bambino'), (24, '1'), (21, 'sviluppo'), (21, 'sicuramente'), (21, 'sempre'), (21, 'reale'), (21, 'meno'), (21, 'fatto'), (21, 'fa'), (21, 'dopo'), (21, 'diciamo'), (21, 'costruire'), (18, 'tipo'), (18, 'stare'), (18, 'solo'), (18, 'secondo'),
, 'seguito'), (6, 'seconda'), (6, 'scusa'), (6, 'scolastica'), (6, 'scelta'), (6, 'sapere'), (6, 'risposte'), (6, 'riesce'), (6, 'ricominciare'), (6, 'realizzare'), (6, 'raggiungimento'), (6, 'qualcosa'), (6, 'qua'), (6, 'pure'), (6, 'puoi'), (6, 'proposte'), (6, 'proposta'), (6, 'proponevo'), (6, 'praticamente'), (6, 'potuto'), (6, 'poterlo'), (6, 'poter'), (6, 'possano'), (6, 'porta'), (6, 'persone'), (6, 'periodo'), (6, 'percorso'), (6, 'peraltro'), (6, 'pensavo'), (6, 'pensando'), (6, 'partecipare'), (6, 'parola'), (6, 'parlo'), (6, 'necessità'), (6, 'multe'), (6, 'movimenti'), (6, 'mettersi'), (6, 'mettere'), (6, 'master'), (6, 'mare'), (6, 'mangiare'), (6, 'manca'), (6, 'malaguzzi'), (6, 'mai'), (6, 'luminosa'), (6, 'logico'), (6, 'linterazione'), (6, 'limitata'), (6, 'lavora'), (6, 'lavagna'), (6, 'laltro'), (6, 'interessa'), (6, 'intelligente'), (6, 'insegnanti'), (6, 'insegnante'), (6, 'immaginazioni'), ...

# %%
for v,k in tmp[:1000]:
    print(k,v)
# Out:
# bambini 120
# essere 99
# molto 90
# poi 63
# attività 51
# materiali 45
# esempio 42
# so 36
# fare 36
# stanza 33
# anni 33
# scuola 30
# punto 27
# interessante 27
# importante 24
# dire 24
# dentro 24
# bambino 24
# 1 24
# sviluppo 21
# sicuramente 21
# sempre 21
# reale 21
# meno 21
# fatto 21
# fa 21
# dopo 21
# diciamo 21
# costruire 21
# tipo 18
# stare 18
# solo 18
# secondo 18
# possiamo 18
# lavoro 18
# diverse 18
# così 18
# compito 18
# competenze 18
# altri 18
# vita 15
# vista 15
# tanto 15
# senso 15
# realtà 15
# prima 15
# penso 15
# parte 15
# obiettivi 15
# movimento 15
# modo 15
# materiale 15
# mano 15
# immagini 15
# fuori 15
# diversi 15
# creatività 15
# civiltà 15
# capire 15
# Magic 15
# Insomma 15
# Come 15
# Adesso 15
# visto 12
# viene 12
# veramente 12
# vedo 12
# usare 12
# trovare 12
# tema 12
# suoni 12
# strutturate 12
# scuole 12
# room 12
# quando 12
# primaria 12
# posso 12
# magica 12
# livello 12
# lavorato 12
# immagino 12
# disturbo 12
# detto 12
# dellimmaginazione 12
# costruzione 12
# cose 12
# corpo 12
# contesto 12
# certo 12
# avere 12
# aiutare 12
# Dove 12
# Camilla 12
# vero 9
# vengono 9
# vedere 9
# vale 9
# vabbè 9
# va 9
# unesperienza 9
# unattività 9
# tutte 9
# tempo 9
# tecnologico 9
# studio 9
# stimolazioni 9
# sente 9
# seguire 9
# scheda 9
# riesco 9
# relazione 9
# quali 9
# preparare 9
# possibilità 9
# possa 9
# pezzo 9
# pensato 9
# pensare 9
# ovviamente 9
# oppure 9
# oggettive 9
# niente 9
# muovono 9
# mondo 9
# momento 9
# molte 9
# mente 9
# lesperienza 9
# lavorare 9
# intanto 9
# infatti 9
# idee 9
# gruppo 9
# forse 9
# forme 9
# fermo 9
# esprimersi 9
# domande 9
# diversa 9
# devono 9
# deve 9
# determinate 9
# dare 9
# credo 9
# creativo 9
# creare 9
# caso 9
# capito 9
# autistico 9
# apprendimenti 9
# altre 9
# allinterno 9
# aiuta 9
# Secondo 9
# Monica 9
# Forse 9
# Camera 9
# 10 9
# voglio 6
# voglia 6
# trovato 6
# tre 6
# toccando 6
# tipi 6
# testa 6
# tecnologia 6
# tatto 6
# tante 6
# sviluppa 6
# successo 6
# succede 6
# strutturati 6
# stimolare 6
# stimolante 6
# stesso 6
# spettro 6
# spento 6
# spazi 6
# sotto 6
# sostegno 6
# sorprendenti 6
# soprattutto 6
# soluzione 6
# solito 6
# sociale 6
# situazioni 6
# servizi 6
# sera 6
# senza 6
# semplicemente 6
# seguo 6
# seguito 6
# seconda 6
# scusa 6
# scolastica 6
# scelta 6
# sapere 6
# risposte 6
# riesce 6
# ricominciare 6
# realizzare 6
# raggiungimento 6
# qualcosa 6
# qua 6
# pure 6
# puoi 6
# proposte 6
# proposta 6
# proponevo 6
# praticamente 6
# potuto 6
# poterlo 6
# poter 6
# possano 6
# porta 6
# persone 6
# periodo 6
# percorso 6
# peraltro 6
# pensavo 6
# pensando 6
# partecipare 6
# parola 6
# parlo 6
# necessità 6
# multe 6
# movimenti 6
# mettersi 6
# mettere 6
# master 6
# mare 6
# mangiare 6
# manca 6
# malaguzzi 6
# mai 6
# luminosa 6
# logico 6
# linterazione 6
# limitata 6
# lavora 6
# lavagna 6
# laltro 6
# interessa 6
# intelligente 6
# insegnanti 6
# insegnante 6
# immaginazioni 6
# immaginare 6
# grossa 6
# grazie 6
# grande 6
# gioco 6
# funzionamento 6
# focus 6
# flessibile 6
# finché 6
# facete 6
# esperienze 6
# esperienza 6
# elementi 6
# effetti 6
# eccetera 6
# dovremmo 6
# diverso 6
# disposizione 6
# digitale 6
# difficili 6
# dice 6
# detta 6
# davanti 6
# creativi 6
# compiti 6
# collegamento 6
# collegamente 6
# classe 6
# certi 6
# casa 6
# campo 6
# brutta 6
# bimbo 6
# ben 6
# bello 6
# base 6
# azione 6
# avvengono 6
# avvantaggiare 6
# attivare 6
# attimo 6
# anno 6
# ambiti 6
# ambientazioni 6
# alcune 6
# aiutarlo 6
# aggiungere 6
# aggettivi 6
# Va 6
# Sono 6
# Sofia 6
# Sia 6
# Questi 6
# Preparare 6
# Più 6
# I 6
# Ho 6
# Grazie 6
# Ecco 6
# Diciamo 6
# Dei 6
# Ci 6
# Attività 6
# 50 6
# ziua 3
# zero 3
# wound 3
# whitacre 3
# vuole 3
# vuoi 3
# volete 3
# vogliono 3
# vogliamo 3
# visti 3
# visive 3
# virtualmente 3
# virtuale 3
# vino 3
# vicino 3
# via 3
# vestiti 3
# vestirsi 3
# veri 3
# verbale 3
# veniva 3
# venire 3
# veloci 3
# vedono 3
# vedeva 3
# ve 3
# vario 3
# varietà 3
# vantaggio 3
# vantaggi 3
# vanno 3
# vado 3
# utilizziamo 3
# utilizzarli 3
# utilizzare 3
# utilizzano 3
# utilità 3
# utile 3
# uomini 3
# unipotesi 3
# uninterazione 3
# uninsegnante 3
# unimore 3
# unidea 3
# uneventuale 3
# unaula 3
# unaltra 3
# Fa 3
# Esterno 3

# %%
word= ['Quindi']
with open('filteredtext616.txt', 'r') as infile:
    newlist= [i for i in infile.read().split() if i!=word]
with open('filteredtext616.txt','w') as outfile:
    outfile.write("\n".join(newlist))

# %%
infile = "focus_group1.txt"
outfile = "cleaned_file1.txt"

delete_list = ["fare\n", " se\n", " quello\n"]
fin = open(infile)
fout = open(outfile, "w+")
for line in fin:
    for word in delete_list:
        line = line.replace(word, "")
    fout.write(line)
fin.close()
fout.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-569cb743b609> in <module>
#       3
#       4 delete_list = ["fare\n", " se\n", " quello\n"]
# ----> 5 fin = open(infile)
#       6 fout = open(outfile, "w+")
#       7 for line in fin:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'focus_group1.txt'

# %%
conda install -c conda-forge wordcloud
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38h50d1736_3         3.1 MB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     wordcloud-1.8.1            |   py38h96a0964_1         170 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/osx-64::python_abi-3.8-2_cp38
#   wordcloud          conda-forge/osx-64::wordcloud-1.8.1-py38h96a0964_1
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.3-py38_0 --> conda-forge::conda-4.10.3-py38h50d1736_3
#
#
#
# Downloading and Extracting Packages
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# conda-4.10.3         | 3.1 MB    | ##################################### | 100%
# wordcloud-1.8.1      | 170 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     conda-4.10.3               |   py38hecd8cb5_0         2.9 MB
#     conda-package-handling-1.7.3|   py38h9ed2024_1         1.5 MB
#     xmltodict-0.12.0           |     pyhd3eb1b0_0          13 KB
#     ------------------------------------------------------------
#                                            Total:         4.4 MB
#
# The following packages will be UPDATED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#   conda-package-han~                   1.6.1-py38h1de35cc_0 --> 1.7.3-py38h9ed2024_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              conda-forge::conda-4.10.3-py38h50d173~ --> pkgs/main::conda-4.10.3-py38hecd8cb5_0
#
# The following packages will be DOWNGRADED:
#
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
# conda-package-handli | 1.5 MB    | ##################################### | 100%
# xmltodict-0.12.0     | 13 KB     | ##################################### | 100%
# conda-4.10.3         | 2.9 MB    | ##################################### | 100%
# backports.tempfile-1 | 11 KB     | ##################################### | 100%
# backports.functools_ | 9 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS


def random_color_func(word=None, font_size=None, position=None, orientation=None, font_path=None, random_state=None):
    h = int(360.0 * 100.0 / 255.0)
    s = int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(60, 120)) / 255.0)

    return "hsl({}, {}%, {}%)".format(h, s, l)

file_content=open ("filteredtext9.txt").read()

wordcloud = WordCloud(font_path = r'/Users/sofya/Library/Fonts/Verdana.ttf',
                            stopwords = STOPWORDS,
                            background_color = 'white',
                            width = 2000,
                            height = 1500,
                            color_func = random_color_func
                            ).generate(file_content)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
plt.draw()

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

file_docs = []

with open ('filteredtext7.txt') as f:
    tokens = sent_tokenize(f.read())
    for line in tokens:
        file_docs.append(line)

print("Number of documents:",len(file_docs))
# Out:
# Number of documents: 8

# %%
# creating a variable and storing the text
# that we want to search
search_text = "autistici"
  
# creating a variable and storing the text
# that we want to add
replace_text = "autistico"
  
# Opening our text file in read only
# mode using the open() function
with open(r'filteredtext9.txt', 'r') as file:
  
    # Reading the content of the file
    # using the read() function and storing
    # them in a new variable
    data = file.read()
  
    # Searching and replacing the text
    # using the replace() function
    data = data.replace(search_text, replace_text)
  
# Opening our text file in write only
# mode to write the replaced content
with open(r'filteredtext9.txt', 'w') as file:
  
    # Writing the replaced data in our
    # text file
    file.write(data)
  
# Printing Text replaced
print("Text replaced")
# Out:
# Text replaced

# %%
infile = "filteredtext6.txt"
outfile = "cleaned_file6.txt"

delete_list = ["ah", "sì", "ma"]
with open(infile) as fin, open(outfile, "w+") as fout:
    for line in fin:
        for word in delete_list:
            line = line.replace(word, "")
            fout.write(line)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.8/site-packages (1.0.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

words = [('creatività', 24), ('attività', 33), ('ragazzo', 30), ('fatto', 25), ('esempio', 34), 
         ('stanza', 18), ('spazio', 18), ('domande', 17), ('penso', 30), ('musica', 25), 
         ('lavorato', 18),('autistico', 23), ('sostegno', 13), ('bambino', 75),
         ('esperienza', 23), ('ambiente', 23), ('room', 22), ('scuola', 21), ('magic', 19)] 


sizes, labels = [i[1] for i in words],[i[0] for i in words]
plt.pie(sizes, labels=labels,autopct='%1.1i%%')
plt.show()

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /opt/anaconda3/lib/python3.8/site-packages (4.1.2)
# Requirement already satisfied: scipy>=0.18.1 in /opt/anaconda3/lib/python3.8/site-packages (from gensim) (1.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/lib/python3.8/site-packages (from gensim) (1.18.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the libraries 
import nltk
from nltk.corpus import stopwords
print(stopwords.words('italian'))
# Out:
# ['ad', 'al', 'allo', 'ai', 'agli', 'all', 'agl', 'alla', 'alle', 'con', 'col', 'coi', 'da', 'dal', 'dallo', 'dai', 'dagli', 'dall', 'dagl', 'dalla', 'dalle', 'di', 'del', 'dello', 'dei', 'degli', 'dell', 'degl', 'della', 'delle', 'in', 'nel', 'nello', 'nei', 'negli', 'nell', 'negl', 'nella', 'nelle', 'su', 'sul', 'sullo', 'sui', 'sugli', 'sull', 'sugl', 'sulla', 'sulle', 'per', 'tra', 'contro', 'io', 'tu', 'lui', 'lei', 'noi', 'voi', 'loro', 'mio', 'mia', 'miei', 'mie', 'tuo', 'tua', 'tuoi', 'tue', 'suo', 'sua', 'suoi', 'sue', 'nostro', 'nostra', 'nostri', 'nostre', 'vostro', 'vostra', 'vostri', 'vostre', 'mi', 'ti', 'ci', 'vi', 'lo', 'la', 'li', 'le', 'gli', 'ne', 'il', 'un', 'uno', 'una', 'ma', 'ed', 'se', 'perché', 'anche', 'come', 'dov', 'dove', 'che', 'chi', 'cui', 'non', 'più', 'quale', 'quanto', 'quanti', 'quanta', 'quante', 'quello', 'quelli', 'quella', 'quelle', 'questo', 'questi', 'questa', 'queste', 'si', 'tutto', 'tutti', 'a', 'c', 'e', 'i', 'l', 'o', 'ho', 'hai', 'ha', 'abbiamo', 'avete', 'hanno', 'abbia', 'abbiate', 'abbiano', 'avrò', 'avrai', 'avrà', 'avremo', 'avrete', 'avranno', 'avrei', 'avresti', 'avrebbe', 'avremmo', 'avreste', 'avrebbero', 'avevo', 'avevi', 'aveva', 'avevamo', 'avevate', 'avevano', 'ebbi', 'avesti', 'ebbe', 'avemmo', 'aveste', 'ebbero', 'avessi', 'avesse', 'avessimo', 'avessero', 'avendo', 'avuto', 'avuta', 'avuti', 'avute', 'sono', 'sei', 'è', 'siamo', 'siete', 'sia', 'siate', 'siano', 'sarò', 'sarai', 'sarà', 'saremo', 'sarete', 'saranno', 'sarei', 'saresti', 'sarebbe', 'saremmo', 'sareste', 'sarebbero', 'ero', 'eri', 'era', 'eravamo', 'eravate', 'erano', 'fui', 'fosti', 'fu', 'fummo', 'foste', 'furono', 'fossi', 'fosse', 'fossimo', 'fossero', 'essendo', 'faccio', 'fai', 'facciamo', 'fanno', 'faccia', 'facciate', 'facciano', 'farò', 'farai', 'farà', 'faremo', 'farete', 'faranno', 'farei', 'faresti', 'farebbe', 'faremmo', 'fareste', 'farebbero', 'facevo', 'facevi', 'faceva', 'facevamo', 'facevate', 'facevano', 'feci', 'facesti', 'fece', 'facemmo', 'faceste', 'fecero', 'facessi', 'facesse', 'facessimo', 'facessero', 'facendo', 'sto', 'stai', 'sta', 'stiamo', 'stanno', 'stia', 'stiate', 'stiano', 'starò', 'starai', 'starà', 'staremo', 'starete', 'staranno', 'starei', 'staresti', 'starebbe', 'staremmo', 'stareste', 'starebbero', 'stavo', 'stavi', 'stava', 'stavamo', 'stavate', 'stavano', 'stetti', 'stesti', 'stette', 'stemmo', 'steste', 'stettero', 'stessi', 'stesse', 'stessimo', 'stessero', 'stando', 'però', 'ecco', 'ee', 'quindi', 'eh', 'Eh', 'cioè', 'ma', 'quel', 'allora', 'ah', 'sì', 'si.', 'si', 'eh sì', 'sì ma', 'va bene', 'anch io', 'allora', 'io', 'anch', 'Allora', 'E', 'io', 'Ah ', 'Eh\t', 'Va ', 'bene', 'Ma', 'anche', 'Però', 'però', 'ecco', 'ee', 'quindi', 'eh', 'Eh', 'cioè', 'ma', 'quel', 'allora', 'ah', 'sì', 'si.', 'si', 'eh sì', 'sì ma', 'va bene', 'anch io', 'allora', 'io', 'anch', 'Allora', 'E', 'io', 'Ah ', 'Eh\t', 'Va ', 'bene', 'Ma', 'anche', 'Però', 'no', 'po', 'Poi', 'possono', 'e', 'appunto', 'me', 'invece', 'può', 'potrebbe', 'Quindi', 'Ah', 'adesso', 'Per', 'sì', 'magari', 'insomma', 'cè', 'cosa', 'Un', 'Sì', 'Non', 'Cioè', 'Che', 'proprio', 'Il', 'EE', 'di', 'che', 'Si', 'Perché', 'No', 'Eh', 'ecco', 'a', 'Però', 'Io', 'Ha', 'Di', 'A', 'te', 'lì', 'io', 'In', 'per', 'dei', 'Se', 'La', 'Anche', 'AA', 'È', 'ma', 'le', 'la', 'già', 'eh', 'do', 'cioè', 'Questo', 'Poi', 'Le', 'Cè', 'è', 'un', 'sé', 'si', 'se', 'sai', 'qui', 'più', 'noi', 'mi', 'li', 'ha', 'ce', 'anchio', 'Una', 'molto', 'molta', 'molti', 'moltissimo', 'poter', 'potrei', 'potrebbe', 'potrebbero', 'essere', 'potevano', 'potevo', 'poteva', 'potersi', 'poterlo', 'poterlo', 'potere', 'poter', 'potuto', 'possono', 'posso', 'poter', 'potrei', 'potrebbero', 'potrebbe', 'potevo', 'potevano', 'poteva', 'potersi', 'poterlo', 'potere', 'poter', 'potuto', 'possono', 'posso', 'Po']

# %%
import nltk
stopwords = nltk.corpus.stopwords.words('italian')
new_words=('va','Va', 'bene', 'no','a','così', 'Poi', 'Però','Che', 'È', 'E','ne','I', 'Allora', 'Quindi')
for i in new_words:
    stopwords.append(i)
print(stopwords)
# Out:
# ['ad', 'al', 'allo', 'ai', 'agli', 'all', 'agl', 'alla', 'alle', 'con', 'col', 'coi', 'da', 'dal', 'dallo', 'dai', 'dagli', 'dall', 'dagl', 'dalla', 'dalle', 'di', 'del', 'dello', 'dei', 'degli', 'dell', 'degl', 'della', 'delle', 'in', 'nel', 'nello', 'nei', 'negli', 'nell', 'negl', 'nella', 'nelle', 'su', 'sul', 'sullo', 'sui', 'sugli', 'sull', 'sugl', 'sulla', 'sulle', 'per', 'tra', 'contro', 'io', 'tu', 'lui', 'lei', 'noi', 'voi', 'loro', 'mio', 'mia', 'miei', 'mie', 'tuo', 'tua', 'tuoi', 'tue', 'suo', 'sua', 'suoi', 'sue', 'nostro', 'nostra', 'nostri', 'nostre', 'vostro', 'vostra', 'vostri', 'vostre', 'mi', 'ti', 'ci', 'vi', 'lo', 'la', 'li', 'le', 'gli', 'ne', 'il', 'un', 'uno', 'una', 'ma', 'ed', 'se', 'perché', 'anche', 'come', 'dov', 'dove', 'che', 'chi', 'cui', 'non', 'più', 'quale', 'quanto', 'quanti', 'quanta', 'quante', 'quello', 'quelli', 'quella', 'quelle', 'questo', 'questi', 'questa', 'queste', 'si', 'tutto', 'tutti', 'a', 'c', 'e', 'i', 'l', 'o', 'ho', 'hai', 'ha', 'abbiamo', 'avete', 'hanno', 'abbia', 'abbiate', 'abbiano', 'avrò', 'avrai', 'avrà', 'avremo', 'avrete', 'avranno', 'avrei', 'avresti', 'avrebbe', 'avremmo', 'avreste', 'avrebbero', 'avevo', 'avevi', 'aveva', 'avevamo', 'avevate', 'avevano', 'ebbi', 'avesti', 'ebbe', 'avemmo', 'aveste', 'ebbero', 'avessi', 'avesse', 'avessimo', 'avessero', 'avendo', 'avuto', 'avuta', 'avuti', 'avute', 'sono', 'sei', 'è', 'siamo', 'siete', 'sia', 'siate', 'siano', 'sarò', 'sarai', 'sarà', 'saremo', 'sarete', 'saranno', 'sarei', 'saresti', 'sarebbe', 'saremmo', 'sareste', 'sarebbero', 'ero', 'eri', 'era', 'eravamo', 'eravate', 'erano', 'fui', 'fosti', 'fu', 'fummo', 'foste', 'furono', 'fossi', 'fosse', 'fossimo', 'fossero', 'essendo', 'faccio', 'fai', 'facciamo', 'fanno', 'faccia', 'facciate', 'facciano', 'farò', 'farai', 'farà', 'faremo', 'farete', 'faranno', 'farei', 'faresti', 'farebbe', 'faremmo', 'fareste', 'farebbero', 'facevo', 'facevi', 'faceva', 'facevamo', 'facevate', 'facevano', 'feci', 'facesti', 'fece', 'facemmo', 'faceste', 'fecero', 'facessi', 'facesse', 'facessimo', 'facessero', 'facendo', 'sto', 'stai', 'sta', 'stiamo', 'stanno', 'stia', 'stiate', 'stiano', 'starò', 'starai', 'starà', 'staremo', 'starete', 'staranno', 'starei', 'staresti', 'starebbe', 'staremmo', 'stareste', 'starebbero', 'stavo', 'stavi', 'stava', 'stavamo', 'stavate', 'stavano', 'stetti', 'stesti', 'stette', 'stemmo', 'steste', 'stettero', 'stessi', 'stesse', 'stessimo', 'stessero', 'stando', 'però', 'ecco', 'ee', 'quindi', 'eh', 'Eh', 'cioè', 'ma', 'quel', 'allora', 'ah', 'sì', 'si.', 'si', 'eh sì', 'sì ma', 'va bene', 'anch io', 'allora', 'io', 'anch', 'Allora', 'E', 'io', 'Ah ', 'Eh\t', 'Va ', 'bene', 'Ma', 'anche', 'Però', 'però', 'ecco', 'ee', 'quindi', 'eh', 'Eh', 'cioè', 'ma', 'quel', 'allora', 'ah', 'sì', 'si.', 'si', 'eh sì', 'sì ma', 'va bene', 'anch io', 'allora', 'io', 'anch', 'Allora', 'E', 'io', 'Ah ', 'Eh\t', 'Va ', 'bene', 'Ma', 'anche', 'Però', 'no', 'po', 'Poi', 'possono', 'e', 'appunto', 'me', 'invece', 'può', 'potrebbe', 'Quindi', 'Ah', 'adesso', 'Per', 'sì', 'magari', 'insomma', 'cè', 'cosa', 'Un', 'Sì', 'Non', 'Cioè', 'Che', 'proprio', 'Il', 'EE', 'di', 'che', 'Si', 'Perché', 'No', 'Eh', 'ecco', 'a', 'Però', 'Io', 'Ha', 'Di', 'A', 'te', 'lì', 'io', 'In', 'per', 'dei', 'Se', 'La', 'Anche', 'AA', 'È', 'ma', 'le', 'la', 'già', 'eh', 'do', 'cioè', 'Questo', 'Poi', 'Le', 'Cè', 'è', 'un', 'sé', 'si', 'se', 'sai', 'qui', 'più', 'noi', 'mi', 'li', 'ha', 'ce', 'anchio', 'Una', 'molto', 'molta', 'molti', 'moltissimo', 'poter', 'potrei', 'potrebbe', 'potrebbero', 'essere', 'potevano', 'potevo', 'poteva', 'potersi', 'poterlo', 'poterlo', 'potere', 'poter', 'potuto', 'possono', 'posso', 'poter', 'potrei', 'potrebbero', 'potrebbe', 'potevo', 'potevano', 'poteva', 'potersi', 'poterlo', 'potere', 'poter', 'potuto', 'possono', 'posso', 'Po', 'va', 'Va', 'bene', 'no', 'a', 'così', 'Poi', 'Però', 'Che', 'È', 'E', 'ne', 'I', 'Allora', 'Quindi']

# %%
import io
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
 
# word_tokenize accepts
# a string as an input, not a file.
stop_words = set(stopwords.words('italian'))
file1 = open("filteredtext.txt")
 
# Use this to read file content as a stream:
line = file1.read()
words = line.split()
for r in words:
    if not r in stop_words:
        appendFile = open('filteredtext02.txt','a')
        appendFile.write(" "+r)
        appendFile.close()

# %%
# example text
fname = input('Enter File: ')
if len(fname) < 1 : fname = 'Focus_Group_Transcribtion.txt'
hand = open(fname)
# removing stopwords
fname = " ".join([word for word in fname.split() if word not in stop_words])
print(fname)
# Out:
# Enter File: filteredtext.txt
# filteredtext.txt

# %%
infile = "filteredtext6.txt"
outfile = "cleaned_file111.txt"

delete_list = ["ah"]
fin = open(infile)
fout = open(outfile, "w+")
for line in fin:
    for word in delete_list:
        line = line.replace(word, "")
    fout.write(line)
fin.close()
fout.close()

# %%
import nltk
from nltk.corpus import stopwords
print(stopwords.words('italian'))
# Out:
# ['ad', 'al', 'allo', 'ai', 'agli', 'all', 'agl', 'alla', 'alle', 'con', 'col', 'coi', 'da', 'dal', 'dallo', 'dai', 'dagli', 'dall', 'dagl', 'dalla', 'dalle', 'di', 'del', 'dello', 'dei', 'degli', 'dell', 'degl', 'della', 'delle', 'in', 'nel', 'nello', 'nei', 'negli', 'nell', 'negl', 'nella', 'nelle', 'su', 'sul', 'sullo', 'sui', 'sugli', 'sull', 'sugl', 'sulla', 'sulle', 'per', 'tra', 'contro', 'io', 'tu', 'lui', 'lei', 'noi', 'voi', 'loro', 'mio', 'mia', 'miei', 'mie', 'tuo', 'tua', 'tuoi', 'tue', 'suo', 'sua', 'suoi', 'sue', 'nostro', 'nostra', 'nostri', 'nostre', 'vostro', 'vostra', 'vostri', 'vostre', 'mi', 'ti', 'ci', 'vi', 'lo', 'la', 'li', 'le', 'gli', 'ne', 'il', 'un', 'uno', 'una', 'ma', 'ed', 'se', 'perché', 'anche', 'come', 'dov', 'dove', 'che', 'chi', 'cui', 'non', 'più', 'quale', 'quanto', 'quanti', 'quanta', 'quante', 'quello', 'quelli', 'quella', 'quelle', 'questo', 'questi', 'questa', 'queste', 'si', 'tutto', 'tutti', 'a', 'c', 'e', 'i', 'l', 'o', 'ho', 'hai', 'ha', 'abbiamo', 'avete', 'hanno', 'abbia', 'abbiate', 'abbiano', 'avrò', 'avrai', 'avrà', 'avremo', 'avrete', 'avranno', 'avrei', 'avresti', 'avrebbe', 'avremmo', 'avreste', 'avrebbero', 'avevo', 'avevi', 'aveva', 'avevamo', 'avevate', 'avevano', 'ebbi', 'avesti', 'ebbe', 'avemmo', 'aveste', 'ebbero', 'avessi', 'avesse', 'avessimo', 'avessero', 'avendo', 'avuto', 'avuta', 'avuti', 'avute', 'sono', 'sei', 'è', 'siamo', 'siete', 'sia', 'siate', 'siano', 'sarò', 'sarai', 'sarà', 'saremo', 'sarete', 'saranno', 'sarei', 'saresti', 'sarebbe', 'saremmo', 'sareste', 'sarebbero', 'ero', 'eri', 'era', 'eravamo', 'eravate', 'erano', 'fui', 'fosti', 'fu', 'fummo', 'foste', 'furono', 'fossi', 'fosse', 'fossimo', 'fossero', 'essendo', 'faccio', 'fai', 'facciamo', 'fanno', 'faccia', 'facciate', 'facciano', 'farò', 'farai', 'farà', 'faremo', 'farete', 'faranno', 'farei', 'faresti', 'farebbe', 'faremmo', 'fareste', 'farebbero', 'facevo', 'facevi', 'faceva', 'facevamo', 'facevate', 'facevano', 'feci', 'facesti', 'fece', 'facemmo', 'faceste', 'fecero', 'facessi', 'facesse', 'facessimo', 'facessero', 'facendo', 'sto', 'stai', 'sta', 'stiamo', 'stanno', 'stia', 'stiate', 'stiano', 'starò', 'starai', 'starà', 'staremo', 'starete', 'staranno', 'starei', 'staresti', 'starebbe', 'staremmo', 'stareste', 'starebbero', 'stavo', 'stavi', 'stava', 'stavamo', 'stavate', 'stavano', 'stetti', 'stesti', 'stette', 'stemmo', 'steste', 'stettero', 'stessi', 'stesse', 'stessimo', 'stessero', 'stando', 'però', 'ecco', 'ee', 'quindi', 'eh', 'Eh', 'cioè', 'ma', 'quel', 'allora', 'ah', 'sì', 'si.', 'si', 'eh sì', 'sì ma', 'va bene', 'anch io', 'allora', 'io', 'anch', 'Allora', 'E', 'io', 'Ah ', 'Eh\t', 'Va ', 'bene', 'Ma', 'anche', 'Però', 'però', 'ecco', 'ee', 'quindi', 'eh', 'Eh', 'cioè', 'ma', 'quel', 'allora', 'ah', 'sì', 'si.', 'si', 'eh sì', 'sì ma', 'va bene', 'anch io', 'allora', 'io', 'anch', 'Allora', 'E', 'io', 'Ah ', 'Eh\t', 'Va ', 'bene', 'Ma', 'anche', 'Però', 'no', 'po', 'Poi', 'possono', 'e', 'appunto', 'me', 'invece', 'può', 'potrebbe', 'Quindi', 'Ah', 'adesso', 'Per', 'sì', 'magari', 'insomma', 'cè', 'cosa', 'Un', 'Sì', 'Non', 'Cioè', 'Che', 'proprio', 'Il', 'EE', 'di', 'che', 'Si', 'Perché', 'No', 'Eh', 'ecco', 'a', 'Però', 'Io', 'Ha', 'Di', 'A', 'te', 'lì', 'io', 'In', 'per', 'dei', 'Se', 'La', 'Anche', 'AA', 'È', 'ma', 'le', 'la', 'già', 'eh', 'do', 'cioè', 'Questo', 'Poi', 'Le', 'Cè', 'è', 'un', 'sé', 'si', 'se', 'sai', 'qui', 'più', 'noi', 'mi', 'li', 'ha', 'ce', 'anchio', 'Una', 'molto', 'molta', 'molti', 'moltissimo', 'poter', 'potrei', 'potrebbe', 'potrebbero', 'essere', 'potevano', 'potevo', 'poteva', 'potersi', 'poterlo', 'poterlo', 'potere', 'poter', 'potuto', 'possono', 'posso', 'poter', 'potrei', 'potrebbero', 'potrebbe', 'potevo', 'potevano', 'poteva', 'potersi', 'poterlo', 'potere', 'poter', 'potuto', 'possono', 'posso', 'Po']

# %%
import nltk
stopwords = nltk.corpus.stopwords.words('italian')
new_words=('va','Va', 'bene', 'no','a','così', 'Poi', 'Però','Che', 'È', 'E','ne','I', 'Allora', 'Quindi')
for i in new_words:
    stopwords.append(i)
print(stopwords)
# Out:
# ['ad', 'al', 'allo', 'ai', 'agli', 'all', 'agl', 'alla', 'alle', 'con', 'col', 'coi', 'da', 'dal', 'dallo', 'dai', 'dagli', 'dall', 'dagl', 'dalla', 'dalle', 'di', 'del', 'dello', 'dei', 'degli', 'dell', 'degl', 'della', 'delle', 'in', 'nel', 'nello', 'nei', 'negli', 'nell', 'negl', 'nella', 'nelle', 'su', 'sul', 'sullo', 'sui', 'sugli', 'sull', 'sugl', 'sulla', 'sulle', 'per', 'tra', 'contro', 'io', 'tu', 'lui', 'lei', 'noi', 'voi', 'loro', 'mio', 'mia', 'miei', 'mie', 'tuo', 'tua', 'tuoi', 'tue', 'suo', 'sua', 'suoi', 'sue', 'nostro', 'nostra', 'nostri', 'nostre', 'vostro', 'vostra', 'vostri', 'vostre', 'mi', 'ti', 'ci', 'vi', 'lo', 'la', 'li', 'le', 'gli', 'ne', 'il', 'un', 'uno', 'una', 'ma', 'ed', 'se', 'perché', 'anche', 'come', 'dov', 'dove', 'che', 'chi', 'cui', 'non', 'più', 'quale', 'quanto', 'quanti', 'quanta', 'quante', 'quello', 'quelli', 'quella', 'quelle', 'questo', 'questi', 'questa', 'queste', 'si', 'tutto', 'tutti', 'a', 'c', 'e', 'i', 'l', 'o', 'ho', 'hai', 'ha', 'abbiamo', 'avete', 'hanno', 'abbia', 'abbiate', 'abbiano', 'avrò', 'avrai', 'avrà', 'avremo', 'avrete', 'avranno', 'avrei', 'avresti', 'avrebbe', 'avremmo', 'avreste', 'avrebbero', 'avevo', 'avevi', 'aveva', 'avevamo', 'avevate', 'avevano', 'ebbi', 'avesti', 'ebbe', 'avemmo', 'aveste', 'ebbero', 'avessi', 'avesse', 'avessimo', 'avessero', 'avendo', 'avuto', 'avuta', 'avuti', 'avute', 'sono', 'sei', 'è', 'siamo', 'siete', 'sia', 'siate', 'siano', 'sarò', 'sarai', 'sarà', 'saremo', 'sarete', 'saranno', 'sarei', 'saresti', 'sarebbe', 'saremmo', 'sareste', 'sarebbero', 'ero', 'eri', 'era', 'eravamo', 'eravate', 'erano', 'fui', 'fosti', 'fu', 'fummo', 'foste', 'furono', 'fossi', 'fosse', 'fossimo', 'fossero', 'essendo', 'faccio', 'fai', 'facciamo', 'fanno', 'faccia', 'facciate', 'facciano', 'farò', 'farai', 'farà', 'faremo', 'farete', 'faranno', 'farei', 'faresti', 'farebbe', 'faremmo', 'fareste', 'farebbero', 'facevo', 'facevi', 'faceva', 'facevamo', 'facevate', 'facevano', 'feci', 'facesti', 'fece', 'facemmo', 'faceste', 'fecero', 'facessi', 'facesse', 'facessimo', 'facessero', 'facendo', 'sto', 'stai', 'sta', 'stiamo', 'stanno', 'stia', 'stiate', 'stiano', 'starò', 'starai', 'starà', 'staremo', 'starete', 'staranno', 'starei', 'staresti', 'starebbe', 'staremmo', 'stareste', 'starebbero', 'stavo', 'stavi', 'stava', 'stavamo', 'stavate', 'stavano', 'stetti', 'stesti', 'stette', 'stemmo', 'steste', 'stettero', 'stessi', 'stesse', 'stessimo', 'stessero', 'stando', 'però', 'ecco', 'ee', 'quindi', 'eh', 'Eh', 'cioè', 'ma', 'quel', 'allora', 'ah', 'sì', 'si.', 'si', 'eh sì', 'sì ma', 'va bene', 'anch io', 'allora', 'io', 'anch', 'Allora', 'E', 'io', 'Ah ', 'Eh\t', 'Va ', 'bene', 'Ma', 'anche', 'Però', 'va', 'Va', 'bene', 'no', 'a', 'così', 'Poi', 'Però', 'Che', 'È', 'E', 'ne', 'I', 'Allora', 'Quindi']

# %%
import io 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words('italian')) 
file1 = open("filteredtext6.txt") 
line = file1.read()# Use this to read file content as a stream: 
words = line.split() 
for r in words: 
    if not r in stop_words: 
        appendFile = open('filteredtext.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()
